# %%
import requests

# Search for members of a category
def get_category_members(category):
    url = f"https://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:{category}&format=json"
    response = requests.get(url)
    data = response.json()
    return data['query']['categorymembers']
    # return data

# Get categories of an article
def get_article_categories(article):
    url = f"https://en.wikipedia.org/w/api.php?action=query&prop=categories&titles={article}&format=json"
    response = requests.get(url)
    data = response.json()
    pages = data['query']['pages']
    page_id = next(iter(pages))
    return pages[page_id].get('categories', [])

# Get table of contents (sections) of an article
def get_table_of_contents(article):
    url = f"https://en.wikipedia.org/w/api.php?action=parse&page={article}&prop=sections&format=json"
    response = requests.get(url)
    data = response.json()
    return data['parse']['sections']

# Search for lists and timelines
def search_lists_and_timelines(search_term):
    url = f"https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch={search_term}&format=json"
    response = requests.get(url)
    data = response.json()
    return data['query']['search']

# %%
category_members = get_category_members("Role-playing_games")
article_categories = get_article_categories("Python (programming language)")
table_of_contents = get_table_of_contents("Python (programming language)")
lists_and_timelines = search_lists_and_timelines("list of role-playing games")

# %%
table_of_contents[-1]
# Out:
# {'toclevel': 1,
#  'level': '2',
#  'line': 'External links',
#  'number': '17',
#  'index': '29',
#  'fromtitle': 'Python_(programming_language)',
#  'byteoffset': 164045,
#  'anchor': 'External_links',
#  'linkAnchor': 'External_links'}

# %%
# infer category members
## max_member controls how many members to return
def get_category_members(category, max_members=1000, limit_per_request=500):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'query',
        'list': 'categorymembers',
        'cmtitle': f'Category:{category}',
        'cmlimit': limit_per_request,  # Maximum number of results per request
        'format': 'json'
    }

    members = []
    total_fetched = 0

    while total_fetched < max_members:
        response = requests.get(url, params=params)
        data = response.json()
        batch_members = data['query']['categorymembers']
        
        members.extend(batch_members)
        total_fetched += len(batch_members)

        # Check if there is a continuation token
        if 'continue' in data and total_fetched < max_members:
            params['cmcontinue'] = data['continue']['cmcontinue']
        else:
            break
    
    # If more members were fetched than max_members, trim the list
    if len(members) > max_members:
        members = members[:max_members]

    return members

# %%
category = "Machine_learning"
members = get_category_members(category, max_members=5)

# %%
members
# Out:
# [{'pageid': 67911196, 'ns': 0, 'title': 'Bayesian learning mechanisms'},
#  {'pageid': 233488, 'ns': 0, 'title': 'Machine learning'},
#  {'pageid': 53587467, 'ns': 0, 'title': 'Outline of machine learning'},
#  {'pageid': 64439717, 'ns': 0, 'title': '80 Million Tiny Images'},
#  {'pageid': 75530149, 'ns': 0, 'title': 'Accelerated Linear Algebra'}]

# %%
# extract infobox
import requests
from bs4 import BeautifulSoup

def get_infobox(article):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'parse',
        'page': article,
        'prop': 'text',
        'format': 'json'
    }

    response = requests.get(url, params=params)
    data = response.json()
    raw_html = data['parse']['text']['*']

    soup = BeautifulSoup(raw_html, 'html.parser')
    infobox = soup.find('table', {'class': 'infobox'})

    if not infobox:
        return None

    infobox_data = {}
    for row in infobox.find_all('tr'):
        header = row.find('th')
        value = row.find('td')
        if header and value:
            key = header.get_text(" ", strip=True)
            val = value.get_text(" ", strip=True)
            infobox_data[key] = val

    return infobox_data

# Example usage
article = "Python (programming language)"
infobox_data = get_infobox(article)
print()
if infobox_data:
    for key, value in infobox_data.items():
        print(f"{key}: {value}")
else:
    print("No infobox found.")
# Out:
# {'Paradigm': 'Multi-paradigm : object-oriented , [1] procedural ( imperative ), functional , structured , reflective', 'Designed\xa0by': 'Guido van Rossum', 'Developer': 'Python Software Foundation', 'First\xa0appeared': '20\xa0February 1991 ; 33 years ago ( 1991-02-20 ) [2]', 'Stable release': '3.12.4 / 6 June 2024 ; 14 days ago ( 6 June 2024 )', 'Typing discipline': 'duck , dynamic , strong ; [3] optional type annotations (since 3.5, but those hints are ignored, except with unofficial tools) [4]', 'OS': 'Tier 1 : 64-bit Linux , macOS ; 64- and 32-bit Windows 10+ [5] Tier 2 : E.g. 32-bit WebAssembly (WASI) Tier 3 : 64-bit FreeBSD , iOS ; e.g. Raspberry Pi OS Unofficial (or has been known to work): Other Unix-like / BSD variants and e.g. Android 5.0+ (official from Python 3.13 planned [6] ) and a few other platforms [7] [8] [9]', 'License': 'Python Software Foundation License', 'Filename extensions': '.py, .pyw, .pyz, [10] .pyi, .pyc, .pyd', 'Website': 'python.org'}
# Paradigm: Multi-paradigm : object-oriented , [1] procedural ( imperative ), functional , structured , reflective
# Designed by: Guido van Rossum
# Developer: Python Software Foundation
# First appeared: 20 February 1991 ; 33 years ago ( 1991-02-20 ) [2]
# Stable release: 3.12.4 / 6 June 2024 ; 14 days ago ( 6 June 2024 )
# Typing discipline: duck , dynamic , strong ; [3] optional type annotations (since 3.5, but those hints are ignored, except with unofficial tools) [4]
# OS: Tier 1 : 64-bit Linux , macOS ; 64- and 32-bit Windows 10+ [5] Tier 2 : E.g. 32-bit WebAssembly (WASI) Tier 3 : 64-bit FreeBSD , iOS ; e.g. Raspberry Pi OS Unofficial (or has been known to work): Other Unix-like / BSD variants and e.g. Android 5.0+ (official from Python 3.13 planned [6] ) and a few other platforms [7] [8] [9]
# License: Python Software Foundation License
# Filename extensions: .py, .pyw, .pyz, [10] .pyi, .pyc, .pyd
# Website: python.org

# %%
def search_lists_and_timelines(search_term):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'query',
        'list': 'search',
        'srsearch': search_term,
        'format': 'json',
        'srlimit': 20  # You can adjust this limit as needed
    }
    response = requests.get(url, params=params)
    data = response.json()
    return data['query']['search'] if 'query' in data else []

# Example usage
search_term = "Python (programming language)"
results = search_lists_and_timelines(search_term)
for result in results:
    print(f"Title: {result['title']}\nSnippet: {result['snippet']}\n")
# Out:
# Title: Python (programming language)
# Snippet: <span class="searchmatch">Python</span> is a high-level, general-purpose <span class="searchmatch">programming</span> <span class="searchmatch">language</span>. Its design philosophy emphasizes code readability with the use of significant indentation
#
# Title: History of Python
# Snippet: The <span class="searchmatch">programming</span> <span class="searchmatch">language</span> <span class="searchmatch">Python</span> was conceived in the late 1980s, and its implementation was started in December 1989 by Guido van Rossum at CWI in the
#
# Title: Mojo (programming language)
# Snippet: Mojo is a <span class="searchmatch">programming</span> <span class="searchmatch">language</span> in the <span class="searchmatch">Python</span> family that is currently under development. It is available both in browsers via Jupyter notebooks, and locally
#
# Title: Python syntax and semantics
# Snippet: The syntax of the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span> is the set of rules that defines how a <span class="searchmatch">Python</span> <span class="searchmatch">program</span> will be written and interpreted (by both the runtime
#
# Title: Stackless Python
# Snippet: Stackless <span class="searchmatch">Python</span>, or Stackless, is a <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span> interpreter, so named because it avoids depending on the C call stack for its own stack
#
# Title: Python Software Foundation
# Snippet: The <span class="searchmatch">Python</span> Software Foundation (PSF) is an American nonprofit organization devoted to the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span>, launched on March 6, 2001. The
#
# Title: Zen of Python
# Snippet: <span class="searchmatch">Python</span> is a collection of 19 &quot;guiding principles&quot; for writing computer <span class="searchmatch">programs</span> that influence the design of the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span>. <span class="searchmatch">Python</span> code
#
# Title: List of Python software
# Snippet: The <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span> is actively used by many people, both in industry and academia, for a wide variety of purposes. Atom, an open source cross-platform
#
# Title: Anaconda (Python distribution)
# Snippet: Anaconda is a distribution of the <span class="searchmatch">Python</span> and R <span class="searchmatch">programming</span> <span class="searchmatch">languages</span> for scientific computing (data science, machine learning applications, large-scale
#
# Title: Python
# Snippet: Australia <span class="searchmatch">Python</span> (genus), a genus of Pythonidae found in Africa and Asia <span class="searchmatch">Python</span> (mythology), a mythical serpent <span class="searchmatch">Python</span> (<span class="searchmatch">programming</span> <span class="searchmatch">language</span>), a widely
#
# Title: Flask (web framework)
# Snippet: is a string handling library for the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span>. The eponymous MarkupSafe type extends the <span class="searchmatch">Python</span> string type and marks its contents as
#
# Title: Quantum programming
# Snippet: Eclipse Foundation and developed in <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> by Fraunhofer FOKUS Qrisp is a high-level <span class="searchmatch">programming</span> <span class="searchmatch">language</span> for creating and compiling quantum
#
# Title: General-purpose programming language
# Snippet: domains. Conversely, a domain-specific <span class="searchmatch">programming</span> <span class="searchmatch">language</span> (DSL) is used within a specific area. For example, <span class="searchmatch">Python</span> is a GPL, while SQL is a DSL for querying
#
# Title: Mod python
# Snippet: mod_<span class="searchmatch">python</span> is an Apache HTTP Server module that integrates the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span> with the server. It is intended to provide a <span class="searchmatch">Python</span> <span class="searchmatch">language</span> binding
#
# Title: PythonAnywhere
# Snippet: <span class="searchmatch">Python</span>Anywhere is an online integrated development environment (IDE) and web hosting service (Platform as a service) based on the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> language
#
# Title: Guido van Rossum
# Snippet: January 1956) is a Dutch programmer. He is the creator of the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span>, for which he was the &quot;benevolent dictator for life&quot; (BDFL) until
#
# Title: IDLE
# Snippet: for <span class="searchmatch">Python</span>, which has been bundled with the default implementation of the <span class="searchmatch">language</span> since 1.5.2b1. It is packaged as an optional part of the <span class="searchmatch">Python</span> packaging
#
# Title: Comparison of multi-paradigm programming languages
# Snippet: Imperative <span class="searchmatch">programming</span> – explicit statements that change a <span class="searchmatch">program</span> state Logic <span class="searchmatch">programming</span> – uses explicit mathematical logic for <span class="searchmatch">programming</span> Metaprogramming
#
# Title: MicroPython
# Snippet: Micro<span class="searchmatch">Python</span> is a software implementation of a <span class="searchmatch">programming</span> <span class="searchmatch">language</span> largely compatible with <span class="searchmatch">Python</span> 3, written in C, that is optimized to run on a microcontroller
#
# Title: Glob (programming)
# Snippet: these same wildcard patterns. Guido van Rossum, author of the <span class="searchmatch">Python</span> <span class="searchmatch">programming</span> <span class="searchmatch">language</span>, wrote and contributed a glob routine to BSD Unix in 1986. There

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_all_wikipedia_tables(article_title):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'parse',
        'page': article_title,
        'prop': 'text',
        'format': 'json'
    }

    response = requests.get(url, params=params)
    data = response.json()
    raw_html = data['parse']['text']['*']

    soup = BeautifulSoup(raw_html, 'html.parser')
    tables = soup.find_all('table', {'class': 'wikitable'})
    
    if not tables:
        return []

    all_tables_data = []
    for table_index, table in enumerate(tables):
        headers = [header.get_text(strip=True) for header in table.find_all('th')]
        table_dict = {header: [] for header in headers}

        for row in table.find_all('tr')[1:]:  # Skip the header row
            cells = row.find_all(['td', 'th'])
            if len(cells) == len(headers):  # Ensure the row has the correct number of cells
                for i, cell in enumerate(cells):
                    table_dict[headers[i]].append(cell.get_text(strip=True))
        
        all_tables_data.append({
            'table_index': table_index,
            'table_data': table_dict
        })

    return all_tables_data

# Example usage
article = "Python (programming language)"
table_data = get_all_wikipedia_tables(article)
if table_data:
    for row in table_data:
        print(row)
else:
    print("No table found.")
# Out:
# {'table_index': 0, 'table_data': {'Type': ['bool', 'bytearray', 'bytes', 'complex', 'dict', 'types.EllipsisType', 'float', 'frozenset', 'int', 'list', 'types.NoneType', 'types.NotImplementedType', 'range', 'set', 'str', 'tuple'], 'Mutability': ['immutable', 'mutable', 'immutable', 'immutable', 'mutable', 'immutable', 'immutable', 'immutable', 'immutable', 'mutable', 'immutable', 'immutable', 'immutable', 'mutable', 'immutable', 'immutable'], 'Description': ['Boolean value', 'Sequence ofbytes', 'Sequence of bytes', 'Complex numberwith real and imaginary parts', 'Associative array(or dictionary) of key and value pairs; can contain mixed types (keys and values), keys must be a hashable type', 'Anellipsisplaceholder to be used as an index inNumPyarrays', 'Double-precisionfloating-point number. The precision is machine-dependent but in practice is generally implemented as a 64-bitIEEE\xa0754number with 53\xa0bits of precision.[118]', 'Unorderedset, contains no duplicates; can contain mixed types, if hashable', 'Integerof unlimited magnitude[119]', 'List, can contain mixed types', 'An object representing the absence of a value, often callednullin other languages', 'A placeholder that can be returned fromoverloaded operatorsto indicate unsupported operand types.', 'Animmutable sequenceof numbers commonly used for looping a specific number of times inforloops[120]', 'Unorderedset, contains no duplicates; can contain mixed types, if hashable', 'Acharacter string: sequence of Unicode codepoints', 'Can contain mixed types'], 'Syntax examples': ['TrueFalse', 'bytearray(b\'Some ASCII\')bytearray(b"Some ASCII")bytearray([119,105,107,105])', 'b\'Some ASCII\'b"Some ASCII"bytes([119,105,107,105])', '3+2.7j3+2.7j', "{'key1':1.0,3:False}{}", '...Ellipsis', '1.33333', "frozenset([4.0,'string',True])", '42', "[4.0,'string',True][]", 'None', 'NotImplemented', 'range(-1,10)range(10,-5,-2)', "{4.0,'string',True}set()", '\'Wikipedia\'"Wikipedia""""Spanningmultiplelines"""Spanningmultiplelines', "(4.0,'string',True)('single element',)()"]}}

# %%
# get pages link to the article
def get_page_links(title):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'query',
        'prop': 'links',
        'titles': title,
        'format': 'json',
        'pllimit': 'max'
    }
    response = requests.get(url, params=params)
    data = response.json()
    page = next(iter(data['query']['pages'].values()))
    return page.get('links', [])

article = "Python (programming language)"
links = get_page_links(article)
links
# Out:
# [{'ns': 0, 'title': '"Hello, World!" program'},
#  {'ns': 0, 'title': '3ds Max'},
#  {'ns': 0, 'title': '?:'},
#  {'ns': 0, 'title': 'ABC (programming language)'},
#  {'ns': 0, 'title': 'ADMB'},
#  {'ns': 0, 'title': 'ALGOL'},
#  {'ns': 0, 'title': 'ALGOL 68'},
#  {'ns': 0, 'title': 'APL (programming language)'},
#  {'ns': 0, 'title': 'ATmega'},
#  {'ns': 0, 'title': 'AVR microcontrollers'},
#  {'ns': 0, 'title': 'Abaqus'},
#  {'ns': 0, 'title': 'Academic Free License'},
#  {'ns': 0, 'title': 'Academic conference'},
#  {'ns': 0, 'title': 'Action selection'},
#  {'ns': 0, 'title': 'Activation function'},
#  {'ns': 0, 'title': 'Ada (programming language)'},
#  {'ns': 0, 'title': 'Advanced Simulation Library'},
#  {'ns': 0, 'title': 'Adversarial machine learning'},
#  {'ns': 0, 'title': 'AlexNet'},
#  {'ns': 0, 'title': 'Alex Graves (computer scientist)'},
#  {'ns': 0, 'title': 'Alex Martelli'},
#  {'ns': 0, 'title': 'Algebra'},
#  {'ns': 0, 'title': 'AlphaFold'},
#  {'ns': 0, 'title': 'AlphaGo'},
#  {'ns': 0, 'title': 'AlphaZero'},
#  {'ns': 0, 'title': 'Alternative terms for free software'},
#  {'ns': 0, 'title': 'Amazon (company)'},
#  {'ns': 0, 'title': 'AmigaOS 4'},
#  {'ns': 0, 'title': 'Amoeba (operating system)'},
#  {'ns': 0, 'title': 'Anaconda (installer)'},
#  {'ns': 0, 'title': 'Analyse-it'},
#  {'ns': 0, 'title': 'Andrew Ng'},
#  {'ns': 0, 'title': 'Android (operating system)'},
#  {'ns': 0, 'title': 'Anonymous function'},
#  {'ns': 0, 'title': 'Anthropic'},
#  {'ns': 0, 'title': 'Apache Groovy'},
#  {'ns': 0, 'title': 'Apache License'},
#  {'ns': 0, 'title': 'Apache webserver'},
#  {'ns': 0, 'title': 'Aphorism'},
#  {'ns': 0, 'title': 'Apple M1'},
#  {'ns': 0, 'title': 'Apple Public Source License'},
#  {'ns': 0, 'title': 'ArXiv (identifier)'},
#  {'ns': 0, 'title': 'Arbitrary-precision arithmetic'},
#  {'ns': 0, 'title': 'ArcGIS'},
#  {'ns': 0, 'title': 'Arithmetic operations'},
#  {'ns': 0, 'title': 'ArkTS'},
#  {'ns': 0, 'title': 'Array index'},
#  {'ns': 0, 'title': 'Array slicing'},
#  {'ns': 0, 'title': 'Artificial intelligence'},
#  {'ns': 0, 'title': 'Artificial neural network'},
#  {'ns': 0, 'title': 'Artistic License'},
#  {'ns': 0, 'title': 'Aspect-oriented programming'},
#  {'ns': 0, 'title': 'Assembly language'},
#  {'ns': 0, 'title': 'Assertion (programming)'},
#  {'ns': 0, 'title': 'Assignment (computer science)'},
#  {'ns': 0, 'title': 'Associative array'},
#  {'ns': 0, 'title': 'Astropy'},
#  {'ns': 0, 'title': 'Asynchronous Server Gateway Interface'},
#  {'ns': 0, 'title': 'Attention (machine learning)'},
#  {'ns': 0, 'title': 'Auto-GPT'},
#  {'ns': 0, 'title': 'Autodesk Softimage'},
#  {'ns': 0, 'title': 'Autoencoder'},
#  {'ns': 0, 'title': 'Automatic differentiation'},
#  {'ns': 0, 'title': 'Automation'},
#  {'ns': 0, 'title': 'Autoregressive model'},
#  {'ns': 0, 'title': 'BASIC'},
#  {'ns': 0, 'title': 'BERT (language model)'},
#  {'ns': 0, 'title': 'BLOOM (language model)'},
#  {'ns': 0, 'title': 'BMDP'},
#  {'ns': 0, 'title': 'BSD licenses'},
#  {'ns': 0, 'title': 'BV4.1 (software)'},
#  {'ns': 0, 'title': 'Backporting'},
#  {'ns': 0, 'title': 'Backpropagation'},
#  {'ns': 0, 'title': 'Backward compatibility'},
#  {'ns': 0, 'title': 'Bard (chatbot)'},
#  {'ns': 0, 'title': 'Batch normalization'},
#  {'ns': 0, 'title': 'Bazel (software)'},
#  {'ns': 0, 'title': 'Beerware'},
#  {'ns': 0, 'title': 'Benevolent dictator for life'},
#  {'ns': 0, 'title': 'Berkeley Software Distribution'},
#  {'ns': 0, 'title': 'Beta release'},
#  {'ns': 0, 'title': 'Bibcode (identifier)'},
#  {'ns': 0, 'title': 'Biopython'},
#  {'ns': 0, 'title': 'Blender (software)'},
#  {'ns': 0, 'title': 'Block (programming)'},
#  {'ns': 0, 'title': 'Boo (programming language)'},
#  {'ns': 0, 'title': 'Boolean value'},
#  {'ns': 0, 'title': 'Break statement'},
#  {'ns': 0, 'title': 'Bug tracker'},
#  {'ns': 0, 'title': 'Byte'},
#  {'ns': 0, 'title': 'Bytecode'},
#  {'ns': 0, 'title': 'C++'},
#  {'ns': 0, 'title': 'C++11'},
#  {'ns': 0, 'title': 'C++17'},
#  {'ns': 0, 'title': 'C11 (C standard revision)'},
#  {'ns': 0, 'title': 'C89 (C version)'},
#  {'ns': 0, 'title': 'C99'},
#  {'ns': 0, 'title': 'CCP Games'},
#  {'ns': 0, 'title': 'CERN'},
#  {'ns': 0, 'title': 'CLPython'},
#  {'ns': 0, 'title': 'CLU (programming language)'},
#  {'ns': 0, 'title': 'COBOL'},
#  {'ns': 0, 'title': 'CPython'},
#  {'ns': 0, 'title': 'CSPro'},
#  {'ns': 0, 'title': 'C (programming language)'},
#  {'ns': 0, 'title': 'C Sharp (programming language)'},
#  {'ns': 0, 'title': 'Cache poisoning'},
#  {'ns': 0, 'title': 'Calculus'},
#  {'ns': 0, 'title': 'Call stack'},
#  {'ns': 0, 'title': 'Capella (notation program)'},
#  {'ns': 0, 'title': 'Centrum Wiskunde & Informatica'},
#  {'ns': 0, 'title': 'Chapel (programming language)'},
#  {'ns': 0, 'title': 'ChatGPT'},
#  {'ns': 0, 'title': 'CherryPy'},
#  {'ns': 0, 'title': 'Chinchilla AI'},
#  {'ns': 0, 'title': 'Chris Lattner'},
#  {'ns': 0, 'title': 'Cinema 4D'},
#  {'ns': 0, 'title': 'CircuitPython'},
#  {'ns': 0, 'title': 'CiteSeerX (identifier)'},
#  {'ns': 0, 'title': 'Class (computer science)'},
#  {'ns': 0, 'title': 'Cluster analysis'},
#  {'ns': 0, 'title': 'Cobra (programming language)'},
#  {'ns': 0, 'title': 'Code readability'},
#  {'ns': 0, 'title': 'CoffeeScript'},
#  {'ns': 0, 'title': 'Combinatorics'},
#  {'ns': 0, 'title': 'Command line interpreter'},
#  {'ns': 0, 'title': 'Commercial software'},
#  {'ns': 0, 'title': 'Common Development and Distribution License'},
#  {'ns': 0, 'title': 'Common Language Runtime'},
#  {'ns': 0, 'title': 'Common Lisp'},
#  {'ns': 0, 'title': 'Community of practice'},
#  {'ns': 0, 'title': 'Comparison of free and open-source software licenses'},
#  {'ns': 0, 'title': 'Comparison of free software for audio'},
#  {'ns': 0, 'title': 'Comparison of integrated development environments'},
#  {'ns': 0, 'title': 'Comparison of numerical-analysis software'},
#  {'ns': 0, 'title': 'Comparison of open-source and closed-source software'},
#  {'ns': 0,
#   'title': 'Comparison of open-source configuration management software'},
#  {'ns': 0, 'title': 'Comparison of open-source operating systems'},
#  {'ns': 0, 'title': 'Comparison of open-source wireless drivers'},
#  {'ns': 0, 'title': 'Comparison of programming languages'},
#  {'ns': 0, 'title': 'Comparison of shopping cart software'},
#  {'ns': 0, 'title': 'Comparison of source-code-hosting facilities'},
#  {'ns': 0, 'title': 'Comparison of statistical packages'},
#  {'ns': 0, 'title': 'Compile time'},
#  {'ns': 0, 'title': 'Compiler'},
#  {'ns': 0, 'title': 'Complex number'},
#  {'ns': 0, 'title': 'Computational learning theory'},
#  {'ns': 0, 'title': 'Computational science'},
#  {'ns': 0, 'title': 'Computer algebra system'},
#  {'ns': 0, 'title': 'Computer file'},
#  {'ns': 0, 'title': 'Computer networking'},
#  {'ns': 0, 'title': 'Computer vision'},
#  {'ns': 0, 'title': 'Concatenation'},
#  {'ns': 0, 'title': 'Conditional (programming)'},
#  {'ns': 0, 'title': 'Contributor License Agreement'},
#  {'ns': 0, 'title': 'Convolution'},
#  {'ns': 0, 'title': 'Convolutional neural network'},
#  {'ns': 0, 'title': 'Copyleft'},
#  {'ns': 0, 'title': 'Coroutine'},
#  {'ns': 0, 'title': 'Creative Commons license'},
#  {'ns': 0, 'title': 'Cross-platform software'},
#  {'ns': 0, 'title': 'CubicWeb'},
#  {'ns': 0, 'title': 'CumFreq'},
#  {'ns': 0, 'title': 'Curly bracket programming language'},
#  {'ns': 0, 'title': 'Cycle detection'},
#  {'ns': 0, 'title': 'Cython'},
#  {'ns': 0, 'title': 'DADiSP'},
#  {'ns': 0, 'title': 'DALL-E'},
#  {'ns': 0, 'title': 'DAP (software)'},
#  {'ns': 0, 'title': 'D (programming language)'},
#  {'ns': 0, 'title': 'Data Desk'},
#  {'ns': 0, 'title': 'Data analytics'},
#  {'ns': 0, 'title': 'Data augmentation'},
#  {'ns': 0, 'title': 'Data mapper pattern'},
#  {'ns': 0, 'title': 'Data type'},
#  {'ns': 0, 'title': 'Database'},
#  {'ns': 0, 'title': 'Dataplot'},
#  {'ns': 0, 'title': 'David Silver (computer scientist)'},
#  {'ns': 0, 'title': 'Debian Free Software Guidelines'},
#  {'ns': 0, 'title': 'Decimal floating point'},
#  {'ns': 0, 'title': 'Deep learning'},
#  {'ns': 0, 'title': 'Deep learning speech synthesis'},
#  {'ns': 0, 'title': 'Definite clause grammar'},
#  {'ns': 0, 'title': 'Definition of Free Cultural Works'},
#  {'ns': 0, 'title': 'Demis Hassabis'},
#  {'ns': 0, 'title': 'Denial-of-service attack'},
#  {'ns': 0, 'title': 'Design by contract'},
#  {'ns': 0, 'title': 'Device driver'},
#  {'ns': 0, 'title': 'Differentiable function'},
#  {'ns': 0, 'title': 'Differentiable neural computer'},
#  {'ns': 0, 'title': 'Differentiable programming'},
#  {'ns': 0, 'title': 'Diffusion process'},
#  {'ns': 0, 'title': 'Digital image processing'},
#  {'ns': 0, 'title': 'Digital rights management'},
#  {'ns': 0, 'title': 'Dispose pattern'},
#  {'ns': 0, 'title': 'Django (web framework)'},
#  {'ns': 0, 'title': 'Documentation'},
#  {'ns': 0, 'title': 'Doi (identifier)'},
#  {'ns': 0, 'title': 'Double-precision floating-point format'},
#  {'ns': 0, 'title': 'Doxygen'},
#  {'ns': 0, 'title': 'Dropbox (service)'},
#  {'ns': 0, 'title': 'Duck typing'},
#  {'ns': 0, 'title': 'Dylan (programming language)'},
#  {'ns': 0, 'title': 'Dynamic type'},
#  {'ns': 0, 'title': 'Dynamic typing'},
#  {'ns': 0, 'title': 'ECMAScript'},
#  {'ns': 0, 'title': 'EViews'},
#  {'ns': 0, 'title': 'Echo state network'},
#  {'ns': 0, 'title': 'Eclipse Public License'},
#  {'ns': 0, 'title': 'EleutherAI'},
#  {'ns': 0, 'title': 'Ellipsis (programming operator)'},
#  {'ns': 0, 'title': 'End-of-life product'},
#  {'ns': 0, 'title': 'Epi Info'},
#  {'ns': 0, 'title': 'Eric Python IDE'},
#  {'ns': 0, 'title': 'Erlang (programming language)'},
#  {'ns': 0, 'title': 'Escape character'},
#  {'ns': 0, 'title': 'Esri'},
#  {'ns': 0, 'title': 'Euler (software)'},
#  {'ns': 0, 'title': 'Exception handling'},
#  {'ns': 0, 'title': 'Exception handling (programming)'},
#  {'ns': 0, 'title': 'Exception handling syntax'},
#  {'ns': 0, 'title': 'Exponentiation'},
#  {'ns': 0, 'title': 'Expression (computer science)'},
#  {'ns': 0, 'title': 'Extensibility'},
#  {'ns': 0, 'title': 'FEATool Multiphysics'},
#  {'ns': 0, 'title': 'F Sharp (programming language)'},
#  {'ns': 0, 'title': 'Facebook'},
#  {'ns': 0, 'title': 'Facial recognition system'},
#  {'ns': 0, 'title': 'Factorial'},
#  {'ns': 0, 'title': 'FastAPI'},
#  {'ns': 0, 'title': 'Fedora Linux'},
#  {'ns': 0, 'title': 'Fei-Fei Li'},
#  {'ns': 0, 'title': 'Fellow'},
#  {'ns': 0, 'title': 'Filename extension'},
#  {'ns': 0, 'title': 'Finite element method'},
#  {'ns': 0, 'title': 'Firaxis Games'},
#  {'ns': 0, 'title': 'First-class continuations'},
#  {'ns': 0, 'title': 'Flask (web framework)'},
#  {'ns': 0, 'title': 'Floating-point arithmetic'},
#  {'ns': 0, 'title': 'Floor division'},
#  {'ns': 0, 'title': 'Flux (machine-learning framework)'},
#  {'ns': 0, 'title': 'Foobar'},
#  {'ns': 0, 'title': 'Foreach'},
#  {'ns': 0, 'title': 'Fork (software development)'},
#  {'ns': 0, 'title': 'Forth (programming language)'},
#  {'ns': 0, 'title': 'Fortran'},
#  {'ns': 0, 'title': 'Fortress (programming language)'},
#  {'ns': 0, 'title': 'Free-software license'},
#  {'ns': 0, 'title': 'FreeBSD'},
#  {'ns': 0, 'title': 'FreeCAD'},
#  {'ns': 0, 'title': 'FreeFem++'},
#  {'ns': 0, 'title': 'FreeMat'},
#  {'ns': 0, 'title': 'Free Software Foundation'},
#  {'ns': 0, 'title': 'Free Software Movement of India'},
#  {'ns': 0, 'title': 'Free and open-source graphics device driver'},
#  {'ns': 0, 'title': 'Free and open-source software'},
#  {'ns': 0, 'title': 'Free license'},
#  {'ns': 0, 'title': 'Free software'},
#  {'ns': 0, 'title': 'Free software movement'},
#  {'ns': 0, 'title': 'Freeware'},
#  {'ns': 0, 'title': 'Function (computing)'},
#  {'ns': 0, 'title': 'Function (programming)'},
#  {'ns': 0, 'title': 'Functional programming'},
#  {'ns': 0, 'title': 'GAUSS (software)'},
#  {'ns': 0, 'title': 'GDScript'},
#  {'ns': 0, 'title': 'GIMP'},
#  {'ns': 0, 'title': 'GNU Affero General Public License'},
#  {'ns': 0, 'title': 'GNU Debugger'},
#  {'ns': 0, 'title': 'GNU General Public License'},
#  {'ns': 0, 'title': 'GNU Lesser General Public License'},
#  {'ns': 0, 'title': 'GNU Manifesto'},
#  {'ns': 0, 'title': 'GNU Octave'},
#  {'ns': 0, 'title': 'GPT-1'},
#  {'ns': 0, 'title': 'GPT-2'},
#  {'ns': 0, 'title': 'GPT-3'},
#  {'ns': 0, 'title': 'GPT-4'},
#  {'ns': 0, 'title': 'GPT-J'},
#  {'ns': 0, 'title': 'GTK'},
#  {'ns': 0, 'title': 'Garbage collection (computer science)'},
#  {'ns': 0, 'title': 'Gated recurrent unit'},
#  {'ns': 0, 'title': 'Gemini (language model)'},
#  {'ns': 0, 'title': 'General-purpose programming language'},
#  {'ns': 0, 'title': 'Generational list of programming languages'},
#  {'ns': 0, 'title': 'Generative adversarial network'},
#  {'ns': 0, 'title': 'Generator (computer programming)'},
#  {'ns': 0, 'title': 'Generator (computer science)'},
#  {'ns': 0, 'title': 'Genie (programming language)'},
#  {'ns': 0, 'title': 'Genius (mathematics software)'},
#  {'ns': 0, 'title': 'Genstat'},
#  {'ns': 0, 'title': 'Gentoo Linux'},
#  {'ns': 0, 'title': 'Geoffrey Hinton'},
#  {'ns': 0, 'title': 'GitHub'},
#  {'ns': 0, 'title': 'Global interpreter lock'},
#  {'ns': 0, 'title': 'Gmsh'},
#  {'ns': 0, 'title': 'Go (programming language)'},
#  {'ns': 0, 'title': 'Godot (game engine)'},
#  {'ns': 0, 'title': 'Google'},
#  {'ns': 0, 'title': 'Google App Engine'},
#  {'ns': 0, 'title': 'Google DeepMind'},
#  {'ns': 0, 'title': 'Google JAX'},
#  {'ns': 0, 'title': 'Gradient descent'},
#  {'ns': 0, 'title': 'GraphPad InStat'},
#  {'ns': 0, 'title': 'GraphPad Prism'},
#  {'ns': 0, 'title': 'Graph neural network'},
#  {'ns': 0, 'title': 'Graphcore'},
#  {'ns': 0, 'title': 'Graphical user interface'},
#  {'ns': 0, 'title': 'Graphviz'},
#  {'ns': 0, 'title': 'Gratis versus libre'},
#  {'ns': 0, 'title': 'Gretl'},
#  {'ns': 0, 'title': 'Grok (web framework)'},
#  {'ns': 0, 'title': 'Groovy (programming language)'},
#  {'ns': 0, 'title': 'Guido van Rossum'},
#  {'ns': 0, 'title': 'Half-open interval'},
#  {'ns': 0, 'title': 'Hallucination (artificial intelligence)'},
#  {'ns': 0, 'title': 'Handwriting recognition'},
#  {'ns': 0, 'title': 'Hardware description language'},
#  {'ns': 0, 'title': 'Haskell'},
#  {'ns': 0, 'title': 'Here document'},
#  {'ns': 0, 'title': 'High-level programming language'},
#  {'ns': 0, 'title': 'History of Python'},
#  {'ns': 0, 'title': 'History of free and open-source software'},
#  {'ns': 0, 'title': 'History of programming languages'},
#  {'ns': 0, 'title': 'Houdini (software)'},
#  {'ns': 0, 'title': 'Huawei'},
#  {'ns': 0, 'title': 'Huawei PanGu'},
#  {'ns': 0, 'title': 'Hugging Face'},
#  {'ns': 0, 'title': 'Human image synthesis'},
#  {'ns': 0, 'title': 'Hypertext Transfer Protocol'},
#  {'ns': 0, 'title': 'IBM Granite'},
#  {'ns': 0, 'title': 'IBM Watson'},
#  {'ns': 0, 'title': 'IBM Watsonx'},
#  {'ns': 0, 'title': 'IDLE'},
#  {'ns': 0, 'title': 'IDLE (Python)'},
#  {'ns': 0, 'title': 'IEEE 754'},
#  {'ns': 0, 'title': 'IOS'},
#  {'ns': 0, 'title': 'IPython'},
#  {'ns': 0, 'title': 'ISBN (identifier)'},
#  {'ns': 0, 'title': 'ISC license'},
#  {'ns': 0, 'title': 'ISSN (identifier)'},
#  {'ns': 0, 'title': 'ITA Software'},
#  {'ns': 0, 'title': 'Ian Goodfellow'},
#  {'ns': 0, 'title': 'Icon (programming language)'},
#  {'ns': 0, 'title': 'If-then-else'},
#  {'ns': 0, 'title': 'Ilya Sutskever'},
#  {'ns': 0, 'title': 'Image processing'},
#  {'ns': 0, 'title': 'Immutable'},
#  {'ns': 0, 'title': 'Immutable object'},
#  {'ns': 0, 'title': 'Imperative programming'},
#  {'ns': 0, 'title': 'Include directive'},
#  {'ns': 0, 'title': 'Inductive bias'},
#  {'ns': 0, 'title': 'Industrial Light & Magic'},
#  {'ns': 0, 'title': 'Infix notation'},
#  {'ns': 0, 'title': 'InfoWorld'},
#  {'ns': 0, 'title': 'Information geometry'},
#  {'ns': 0, 'title': 'Information security'},
#  {'ns': 0, 'title': 'Inkscape'},
#  {'ns': 0, 'title': 'Instagram'},
#  {'ns': 0, 'title': 'Instance data'},
#  {'ns': 0, 'title': 'Integer (computer science)'},
#  {'ns': 0, 'title': 'Integrated development environment'},
#  {'ns': 0, 'title': 'IronPython'},
#  {'ns': 0, 'title': 'Iterator'},
#  {'ns': 0, 'title': 'JASP'},
#  {'ns': 0, 'title': 'JMP (statistical software)'},
#  {'ns': 0, 'title': 'JMulTi'},
#  {'ns': 0, 'title': 'JavaScript'},
#  {'ns': 0, 'title': 'Java (programming language)'},
#  {'ns': 0, 'title': 'Java (software platform)'},
#  {'ns': 0, 'title': 'Jeff Dean (computer scientist)'},
#  {'ns': 0, 'title': 'Julia (programming language)'},
#  {'ns': 0, 'title': 'Just-in-time compilation'},
#  {'ns': 0, 'title': 'Just-in-time compiler'},
#  {'ns': 0, 'title': 'Just another Gibbs sampler'},
#  {'ns': 0, 'title': 'Jython'},
#  {'ns': 0, 'title': 'Jürgen Schmidhuber'},
#  {'ns': 0, 'title': 'Keras'},
#  {'ns': 0, 'title': 'Kotlin (programming language)'},
#  {'ns': 0, 'title': 'LIMDEP'},
#  {'ns': 0, 'title': 'LISREL'},
#  {'ns': 0, 'title': 'LLVM'},
#  {'ns': 0, 'title': 'LLaMA'},
#  {'ns': 0, 'title': 'LaMDA'},
#  {'ns': 0, 'title': 'LabVIEW'},
#  {'ns': 0, 'title': 'Lambda (programming)'},
#  {'ns': 0, 'title': 'Language binding'},
#  {'ns': 0, 'title': 'Language model'},
#  {'ns': 0, 'title': 'Large language model'},
#  {'ns': 0, 'title': 'Late binding'},
#  {'ns': 0, 'title': 'Lazy evaluation'},
#  {'ns': 0, 'title': 'Lego Mindstorms EV3'},
#  {'ns': 0, 'title': 'LibreOffice'},
#  {'ns': 0, 'title': 'License proliferation'},
#  {'ns': 0, 'title': 'LightWave 3D'},
#  {'ns': 0, 'title': 'Linux'},
#  {'ns': 0, 'title': 'Linux distribution'},
#  {'ns': 0, 'title': 'Lisp (programming language)'},
#  {'ns': 0, 'title': 'List (computer science)'},
#  {'ns': 0, 'title': 'List comprehension'},
#  {'ns': 0, 'title': 'List comprehensions'},
#  {'ns': 0, 'title': 'List of Python software'},
#  {'ns': 0,
#   'title': 'List of commercial open-source applications and services'},
#  {'ns': 0, 'title': 'List of formerly free and open-source software'},
#  {'ns': 0, 'title': 'List of formerly proprietary software'},
#  {'ns': 0, 'title': 'List of free-software events'},
#  {'ns': 0, 'title': 'List of free and open-source Android applications'},
#  {'ns': 0, 'title': 'List of free and open-source iOS applications'},
#  {'ns': 0, 'title': 'List of free and open-source software organizations'},
#  {'ns': 0, 'title': 'List of free and open-source software packages'},
#  {'ns': 0, 'title': 'List of free and open-source web applications'},
#  {'ns': 0, 'title': 'List of free software project directories'},
#  {'ns': 0, 'title': 'List of free television software'},
#  {'ns': 0, 'title': 'List of integrated development environments for Python'},
#  {'ns': 0, 'title': 'List of numerical-analysis software'},
#  {'ns': 0, 'title': 'List of office suites'},
#  {'ns': 0, 'title': 'List of open-source bioinformatics software'},
#  {'ns': 0, 'title': 'List of open-source codecs'},
#  {'ns': 0, 'title': 'List of open-source health software'},
#  {'ns': 0, 'title': 'List of open-source routing platforms'},
#  {'ns': 0, 'title': 'List of open-source software for mathematics'},
#  {'ns': 0, 'title': 'List of open-source video games'},
#  {'ns': 0, 'title': 'List of programming languages'},
#  {'ns': 0, 'title': 'List of programming languages by type'},
#  {'ns': 0, 'title': 'List of statistical software'},
#  {'ns': 0, 'title': 'Lock (computer science)'},
#  {'ns': 0, 'title': 'Logic programming'},
#  {'ns': 0, 'title': 'Long-term support'},
#  {'ns': 0, 'title': 'Long short-term memory'},
#  {'ns': 0, 'title': 'Loss functions for classification'},
#  {'ns': 0, 'title': 'Lua (programming language)'},
#  {'ns': 0, 'title': 'MATLAB'},
#  {'ns': 0, 'title': 'MFEM'},
#  {'ns': 0, 'title': 'MIME'},
#  {'ns': 0,
#   'title': 'MIT Computer Science and Artificial Intelligence Laboratory'},
#  {'ns': 0, 'title': 'MIT License'},
#  {'ns': 0, 'title': 'ML (programming language)'},
#  {'ns': 0, 'title': 'MLwiN'},
#  {'ns': 0, 'title': 'MacOS'},
#  {'ns': 0, 'title': 'Machine learning'},
#  {'ns': 0, 'title': 'Mamba (deep learning)'},
#  {'ns': 0, 'title': 'Maple (software)'},
#  {'ns': 0, 'title': 'Mathcad'},
#  {'ns': 0, 'title': 'Mathematics'},
#  {'ns': 0, 'title': 'Matplotlib'},
#  {'ns': 0, 'title': 'Matrix multiplication'},
#  {'ns': 0, 'title': 'Maya (software)'},
#  {'ns': 0, 'title': 'MedCalc'},
#  {'ns': 0, 'title': 'Memory management'},
#  {'ns': 0, 'title': 'Memristor'},
#  {'ns': 0, 'title': 'Mercurial'},
#  {'ns': 0, 'title': 'Meta AI'},
#  {'ns': 0, 'title': 'Metaclass'},
#  {'ns': 0, 'title': 'Metaobject'},
#  {'ns': 0, 'title': 'Metaprogramming'},
#  {'ns': 0, 'title': 'Metasyntactic variable'},
#  {'ns': 0, 'title': 'Method (computing)'},
#  {'ns': 0, 'title': 'Method (programming)'},
#  {'ns': 0, 'title': 'MicroPython'},
#  {'ns': 0, 'title': 'Microcontroller'},
#  {'ns': 0, 'title': 'Microfit'},
#  {'ns': 0, 'title': 'Microsoft Excel'},
#  {'ns': 0, 'title': 'Microsoft Open Specification Promise'},
#  {'ns': 0, 'title': 'Microsoft Windows'},
#  {'ns': 0, 'title': 'Microthread'},
#  {'ns': 0, 'title': 'Midjourney'},
#  {'ns': 0, 'title': 'Mila (research institute)'},
#  {'ns': 0, 'title': 'MindSpore'},
#  {'ns': 0, 'title': 'Minitab'},
#  {'ns': 0, 'title': 'Mobile app'},
#  {'ns': 0, 'title': 'Mod wsgi'},
#  {'ns': 0, 'title': 'Modo (software)'},
#  {'ns': 0, 'title': 'Modula-3'},
#  {'ns': 0, 'title': 'Modular programming'},
#  {'ns': 0, 'title': 'Modulo operation'},
#  {'ns': 0, 'title': 'Mojo (programming language)'},
#  {'ns': 0, 'title': 'Monty Python'},
#  {'ns': 0, 'title': 'MotionBuilder'},
#  {'ns': 0, 'title': 'Mozilla Public License'},
#  {'ns': 0, 'title': 'Mozilla software rebranded by Debian'},
#  {'ns': 0, 'title': 'MuZero'},
#  {'ns': 0, 'title': 'Multi-paradigm programming language'},
#  {'ns': 0, 'title': 'Multilayer perceptron'},
#  {'ns': 0, 'title': 'Multimedia'},
#  {'ns': 0, 'title': 'Multithreading (computer architecture)'},
#  {'ns': 0, 'title': 'Musical notation'},
#  {'ns': 0, 'title': 'MyHDL'},
#  {'ns': 0, 'title': 'N900'},
#  {'ns': 0, 'title': 'NASA'},
#  {'ns': 0, 'title': 'NCSS (statistical software)'},
#  {'ns': 0, 'title': 'NOP (code)'},
#  {'ns': 0, 'title': 'Name resolution (programming languages)'},
#  {'ns': 0, 'title': 'Natural language processing'},
#  {'ns': 0, 'title': 'Neologism'},
#  {'ns': 0, 'title': 'NetBSD'},
#  {'ns': 0, 'title': 'Netherlands'},
#  {'ns': 0, 'title': 'Neural Turing machine'},
#  {'ns': 0, 'title': 'Neural machine translation'},
#  {'ns': 0, 'title': 'Neuromorphic engineering'},
#  {'ns': 0, 'title': 'Nevow'},
#  {'ns': 0, 'title': 'Nim (programming language)'},
#  {'ns': 0, 'title': 'Ninja-IDE'}]

# %%
# extract image and details.

def get_page_images_with_captions(title):
    url = "https://en.wikipedia.org/w/api.php"
    
    # Step 1: Get the list of images
    params = {
        'action': 'query',
        'prop': 'images',
        'titles': title,
        'format': 'json'
    }
    response = requests.get(url, params=params)
    data = response.json()
    page = next(iter(data['query']['pages'].values()))
    images = page.get('images', [])
    
    # Step 2: Get details for each image
    image_details = []
    for image in images:
        image_title = image['title']
        params = {
            'action': 'query',
            'titles': image_title,
            'prop': 'imageinfo',
            'iiprop': 'url|extmetadata',
            'format': 'json'
        }
        response = requests.get(url, params=params)
        data = response.json()
        image_page = next(iter(data['query']['pages'].values()))
        if 'imageinfo' in image_page:
            image_info = image_page['imageinfo'][0]
            image_url = image_info.get('url', '')
            extmetadata = image_info.get('extmetadata', {})
            caption = extmetadata.get('ImageDescription', {}).get('value', 'No caption available')
            image_details.append({
                'title': image_title,
                'url': image_url,
                'caption': caption
            })
    
    return image_details

# Example usage
title = "Python (programming language)"
images_with_captions = get_page_images_with_captions(title)
for img in images_with_captions:
    print(f"Title: {img['title']}")
    print(f"URL: {img['url']}")
    print(f"Caption: {img['caption']}")
    print()
# Out:
# Title: File:Commons-logo.svg
# URL: https://upload.wikimedia.org/wikipedia/en/4/4a/Commons-logo.svg
# Caption: The Wikimedia Commons logo, SVG version.
#
# Title: File:Free and open-source software logo (2009).svg
# URL: https://upload.wikimedia.org/wikipedia/commons/3/31/Free_and_open-source_software_logo_%282009%29.svg
# Caption: <a href="https://en.wikipedia.org/wiki/FOSS" class="extiw" title="w:FOSS">FOSS</a> logo created in inkscape consisting of a teal colored green square. Text set in Gentium Italic.
#
# Title: File:Guido van Rossum OSCON 2006 cropped.png
# URL: https://upload.wikimedia.org/wikipedia/commons/9/94/Guido_van_Rossum_OSCON_2006_cropped.png
# Caption: <a href="https://nl.wikipedia.org/wiki/Guido_van_Rossum" class="extiw" title="nl:Guido van Rossum">Guido van Rossum</a> op OSCON 2006
#
# Title: File:OOjs UI icon edit-ltr-progressive.svg
# URL: https://upload.wikimedia.org/wikipedia/en/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg
# Caption: <p>English: <span lang="en">An icon from the OOjs UI MediaWiki lib.</span>
# </p>
#
# Title: File:Octicons-terminal.svg
# URL: https://upload.wikimedia.org/wikipedia/commons/6/6f/Octicons-terminal.svg
# Caption: An icon from GitHub octicons, is released under <a rel="nofollow" class="external text" href="https://github.com/github/octicons/blob/master/LICENSE.txt">MIT/SIL</a> license
#
# Title: File:Python-logo-notext.svg
# URL: https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg
# Caption: Python Logo
#
# Title: File:Python 3. The standard type hierarchy-en.svg
# URL: https://upload.wikimedia.org/wikipedia/commons/c/c4/Python_3._The_standard_type_hierarchy-en.svg
# Caption: These are the core data types that come bundled with Python 3. Extension modules (written in C, Java, or other languages, depending on the implementation) can define additional types.
#
# Title: File:Python Powered.png
# URL: https://upload.wikimedia.org/wikipedia/commons/b/bd/Python_Powered.png
# Caption: <a href="https://en.wikipedia.org/wiki/Python_(programming_language)" class="extiw" title="w:Python (programming language)">Python</a> Powered:
# <ul><li><a href="https://en.wikipedia.org/wiki/Linux_Standard_Base" class="extiw" title="w:Linux Standard Base">LSB</a></li>
# <li><a href="https://en.wikipedia.org/wiki/pandas_(software)" class="extiw" title="w:pandas (software)">pandas</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Matplotlib" class="extiw" title="w:Matplotlib">matplotlib</a></li>
# <li><a href="https://en.wikipedia.org/wiki/PyTorch" class="extiw" title="w:PyTorch">PyTorch</a></li>
# <li><a href="https://en.wikipedia.org/wiki/TensorFlow" class="extiw" title="w:TensorFlow">TensorFlow</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Django_(web_framework)" class="extiw" title="w:Django (web framework)">django</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Flask_(web_framework)" class="extiw" title="w:Flask (web framework)">Flask</a></li>
# <li><a href="https://en.wikipedia.org/wiki/GTK" class="extiw" title="w:GTK">GTK</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Qt_(software)" class="extiw" title="w:Qt (software)">Qt</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Universal_Network_Objects" class="extiw" title="w:Universal Network Objects">PyUNO</a></li></ul>
#
# Title: File:Symbol category class.svg
# URL: https://upload.wikimedia.org/wikipedia/en/9/96/Symbol_category_class.svg
# Caption: <p>Symbol for Category-Class on the English Wikipedia
# </p>
#
# Title: File:Symbol list class.svg
# URL: https://upload.wikimedia.org/wikipedia/en/d/db/Symbol_list_class.svg
# Caption: <p>English: <span lang="en">A symbol for list-class articles.</span>
# </p>
